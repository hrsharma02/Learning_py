# %%
from matplotlib import pyplot as plt
import numpy as np
from numpy.random import randn, randint, uniform, sample
# %matplotlib inline
import pandas as pd

# %%
randn(100)
# Out:
# array([ 0.99307597,  0.24164146,  0.5203848 ,  1.29210136, -0.82162985,
#         0.37859557, -1.56974968,  0.84348972, -1.06608325,  0.62581544,
#        -0.74619836,  0.0517393 ,  1.07702817, -0.56048738,  0.92603421,
#        -0.28282842,  0.27976934,  0.42463647,  0.15790123,  0.45943688,
#         0.39637375,  0.38567095, -1.16052108, -0.01494436, -1.75355566,
#         0.91391208, -0.06805008,  0.86576005,  0.28618702, -0.29710349,
#         1.91356131, -0.71051116,  1.46731015, -0.43475598,  0.47664104,
#        -0.1159741 , -2.08393981, -0.8980179 , -0.15747321,  0.34072999,
#         0.30701402, -0.30435895,  0.49594878, -0.51459483,  0.68072635,
#        -0.76557401, -1.67203599, -1.64688719, -0.05887886, -0.11970441,
#         0.44636034, -1.54736025, -0.61248125, -2.18548706, -0.26662468,
#        -2.36769116,  0.40149526, -0.85517192,  0.47357287,  1.44618606,
#         1.43464939, -0.60344411,  0.4744599 ,  0.14544596, -0.8627902 ,
# ...

# %%
pd.DataFrame(randn(100))
# Out:
#            0
# 0   1.505934
# 1  -0.773236
# 2   0.780689
# 3  -0.867006
# 4  -0.128662
# ..       ...
# 95 -0.705728
# 96  0.695751
# 97  0.424525
# 98  1.087414
# 99  1.399063
#
# [100 rows x 1 columns]

# %%
df = pd.DataFrame(randn(1000), index = pd.date_range("2020-10-01", periods=1000), columns=["value"])
ts = pd.Series(randn(1000), index = pd.date_range("2020-10-01", periods = 1000))

# %%
ts.head()
# Out:
# 2020-10-01   -0.811756
# 2020-10-02   -1.293254
# 2020-10-03    0.345556
# 2020-10-04    0.654504
# 2020-10-05    0.123218
# Freq: D, dtype: float64

# %%
ts.plot(figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
ts1 =ts.cumsum()

# %%
ts1.plot(figsize= (5,5))
# Out:
# <AxesSubplot:>

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
iris = sns.load_dataset('iris')
iris.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
sx  = iris.plot(figsize = (15,8), title='Iris Dataset')
sx.set_xlabel('X-Axis')
sx.set_ylabel('Y-Axis')
# Out:
# Text(0, 0.5, 'Y-Axis')

# %%
ts.plot(kind = "bar")
# Out:
# <AxesSubplot:>

# %%
df = iris.drop(['species'], axis = 1)

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
titanic = sns.load_dataset("titanic")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic["pclass"].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
titanic["pclass"].plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
titanic["age"].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1 = pd.DataFrame(randn(10,4), columns = ['a','b','c','d'])
df1.head(10)
# Out:
#           a         b         c         d
# 0 -0.626882  0.648203  1.317483  1.989806
# 1  1.159884  0.138392  0.360433 -0.902759
# 2  1.864951 -1.072116  0.627785 -0.911000
# 3 -0.652815 -1.755110 -1.320266  0.787933
# 4  1.034310  0.821141 -0.551205 -0.026870
# 5 -1.443128 -1.261202  0.445887  0.036167
# 6 -0.072086 -0.009121 -0.615672 -0.589584
# 7 -1.353559 -1.227474 -0.795225 -0.303922
# 8 -0.414716  0.015338  0.146139  0.979982
# 9  1.337808  0.161083  0.474018 -0.273176

# %%
df1.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df1['a'].plot.bar()
# Out:
# <AxesSubplot:>

# %%
iris.plot.hist(figsize=(10,5))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
titanic['age'].plot.hist(figsize=(10,5))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind = 'hist', stacked = True, bins = 10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind = 'hist', stacked = False, bins = 30, orientation = "horizontal")
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
iris["sepal_width"].diff().plot(kind ='hist', stacked = True, bins = 40)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
titanic["age"].diff().plot(kind ='hist', stacked = True, bins = 40)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
titanic["pclass"].diff().plot(kind ='hist', stacked = True, bins = 40)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df2 = iris.drop(['species'], axis = 1)
df2.diff().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1          -0.2         -0.5           0.0          0.0
# 2          -0.2          0.2          -0.1          0.0
# 3          -0.1         -0.1           0.2          0.0
# 4           0.4          0.5          -0.1          0.0

# %%
df2.diff().hist(color ='g', alpha = .5, figsize = (10,10))
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
titanic.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
titanic['fare'].plot.hist(figsize=(10,5))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot.scatter(x = 'sepal_length', y = 'petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df1
# Out:
#           a         b         c         d
# 0 -0.626882  0.648203  1.317483  1.989806
# 1  1.159884  0.138392  0.360433 -0.902759
# 2  1.864951 -1.072116  0.627785 -0.911000
# 3 -0.652815 -1.755110 -1.320266  0.787933
# 4  1.034310  0.821141 -0.551205 -0.026870
# 5 -1.443128 -1.261202  0.445887  0.036167
# 6 -0.072086 -0.009121 -0.615672 -0.589584
# 7 -1.353559 -1.227474 -0.795225 -0.303922
# 8 -0.414716  0.015338  0.146139  0.979982
# 9  1.337808  0.161083  0.474018 -0.273176

# %%
iris.plot.scatter(x = 'sepal_length', y = 'petal_length', c= "sepal_width")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
iris.plot.scatter(x = 'sepal_length', y = 'petal_length', c= "sepal_width", s =100)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length',c= "sepal_width", grid = 10)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
d = df.iloc[0]

# %%
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie(figsize = (10,10))
# Out:
# <AxesSubplot:ylabel='0'>

# %%
d = df.head(3).T

# %%
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots = True, figsize = (20,20))
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
d.plot.pie(subplots = True, figsize = (20,20), fontsize = 20, autopct = '%.2f')
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix
# Out:
# <function pandas.plotting._misc.scatter_matrix(frame, alpha=0.5, figsize=None, ax=None, grid=False, diagonal='hist', marker='.', density_kwds=None, hist_kwds=None, range_padding=0.05, **kwargs)>

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
scatter_matrix(df, figsize = (8,8), diagonal = "kde", color = "r", grid = 10)
plt.show()

# %%
ts.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df1['a'].plot.hist(orientation = "horizontal")
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
df['petal_width'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
ts.plot(style = "g +", label = "Series", legend = True)
# Out:
# <AxesSubplot:>

# %%
df.plot(subplots = True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)
